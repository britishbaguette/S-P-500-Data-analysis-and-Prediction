# %% [markdown]
# The S&P 500 dataset composes stock prices of 500 different American companies across various industries, in a period between early 2013 to early 2018. Each stock’s data is stored in a csv file, where prices such as open, close, highest, lowest and trading volume are recorded on a business daily basis.
#
# Note that the list of companies of S&P 500 are periodically changing due to business activities, such as merging, acquisitions, shrinkage of company’s value and so on. This means those S&P 500 companies in the dataset could be different from those that are today.

# %%
# First import all the modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# Since the dataset does not include background information about the companies, such as industries, year of establishment and so on. It would be hard to classify the companies according to their demographics for the analysis.
#
# To address this issue, the S&P information table on Wikipedia is referenced, which includes their demographics such as founding year, HQ location, sector and so on.

# %%
# Create a function to extract the table from wikipedia
def import_information_table():
    res = requests.get("http://en.wikipedia.org/wiki/List_of_S%26P_500_companies").text
    soup = BeautifulSoup(res, "html.parser")
    table = soup.find("table", id = "constituents")
    return pd.read_html(str(table))[0]

# %%
# Create the table
snf_table = import_information_table()

# %% [markdown]
# Lets look at the columns of the table.

# %%
print(snf_table.columns)
# Out:
# Index(['Symbol', 'Security', 'SEC filings', 'GICS Sector', 'GICS Sub Industry',
#        'Headquarters Location', 'Date first added', 'CIK', 'Founded'],
#       dtype='object')

# %% [markdown]
# It seems the column names are a bit too complicated, lets rename them as below.

# %%
# Rename the columns for easier reading
snf_table.columns = ["symbol", "security", "sec_filings", "sector", "sub_industry", \
                     "hq_location", "date_first_added", "cik", "founded"]

# %% [markdown]
# Now look at the brief structure of the table.

# %%
print(snf_table.head())
# Out:
#   symbol             security sec_filings                  sector  \
# 0    MMM           3M Company     reports             Industrials
# 1    ABT  Abbott Laboratories     reports             Health Care
# 2   ABBV          AbbVie Inc.     reports             Health Care
# 3   ABMD          ABIOMED Inc     reports             Health Care
# 4    ACN        Accenture plc     reports  Information Technology
#
#                      sub_industry              hq_location date_first_added  \
# 0        Industrial Conglomerates      St. Paul, Minnesota       1976-08-09
# 1           Health Care Equipment  North Chicago, Illinois       1964-03-31
# 2                 Pharmaceuticals  North Chicago, Illinois       2012-12-31
# 3           Health Care Equipment   Danvers, Massachusetts       2018-05-31
# 4  IT Consulting & Other Services          Dublin, Ireland       2011-07-06
#
#        cik      founded
# 0    66740         1902
# 1     1800         1888
# 2  1551152  2013 (1888)
# 3   815094         1981
# 4  1467373         1989

# %% [markdown]
# The second column "security" is responsible for the name of the stocks, while the first column "symbol" is their abbreviation and also the name of their data file. (ie. Data of the "3M Company" is stored in the MMM_data.csv file in our folder)
#
# There it seems the most logical way to classify the stocks for the analysis, is by their sector. For facilitate the analysis, a class "Sector" is created, which contains data of all the stocks in that sector.

# %%
# It seems the most appropriate way to classify the stocks is by their industrial sectors.
# A class "Sector" is created, which contains data of all the stocks in that sector.
class Sector:
    def __init__(self, sector_name):
        self.sector_name = sector_name
        self.sector_data_name = snf_table[snf_table["sector"] == sector_name]["symbol"]
        self.df = pd.DataFrame()
        self.sector_dict = {}

    # Importing all stock of the sector
    def import_all_data(self):
        for stock in self.sector_data_name:
            try:
                data_file = open("S&P500 Data/individual_stocks_5yr/individual_stocks_5yr/{name}_data.csv". \
                                 format(name=stock), "r")
                self.sector_dict[stock] = pd.read_csv(data_file)
            except OSError:
                print("This file does not exist: ", stock + "_data.csv")
        self.stock_names = list(self.sector_dict.keys())

    # Create a dataframe which contains the timestamp and all the price and volume data of all the stocks
    def create_dataframe(self):
        self.date = self.sector_dict[self.stock_names[0]]["date"]
        self.df = pd.DataFrame()
        self.df["date"] = self.date
        for stock in self.stock_names:
            self.sector_dict[stock].drop(["date", "Name"], axis=1, inplace=True)
            self.sector_dict[stock].columns = [str(name) + "_" + str(stock) for name in list(self.sector_dict[stock].columns)]
            self.df = self.df.join(self.sector_dict[stock])

    # Create any customized dataframe by choosing what variables to include
    def dataframe_by_price_type(self, type, df = pd.DataFrame()):
        if isinstance(type, str):  type = [type]
        if df.empty:
            df = self.df.copy(deep=True)
        dfvpt = pd.DataFrame(self.date)
        for col_name in list(df.columns)[1:]:
            for name in type:
                if name in col_name:
                    dfvpt = dfvpt.join(df[col_name])
        return dfvpt

    # Create a dataframe for a specific stock
    def stock(self, stock):
        cols = []
        for col in list(self.df.columns):
            if stock in col:
                cols.append(col)
        return pd.DataFrame(self.date).join(self.df[cols])

    # For plotting trend from the dataframe
    @staticmethod
    def plot_trend(df):
        plt.plot(pd.to_datetime(df.iloc[:,0]), df.iloc[:,1:])
        plt.xlabel("Date")
        plt.ylabel("Price (USD)")
        plt.title(
            "Daily Stock Prices trend of {name}".format(name=str(df.columns[1].split("_")[1])))
        plt.grid()
        plt.show()

# %%
print(snf_table["sector"].unique())
# Out:
# ['Industrials' 'Health Care' 'Information Technology'
#  'Communication Services' 'Consumer Discretionary' 'Utilities'
#  'Financials' 'Materials' 'Real Estate' 'Consumer Staples' 'Energy'
#  'Technology']

# %% [markdown]
# Out of the many sectors above,

# %%
finance = Sector("Financials")  # Instantiate a sector object for the financials data

# %% [markdown]
# Import the stock data of the financial sector.
# If the stock exists in the wikipedia table, but not in our data file, it will return the file does not exist.

# %%
finance.import_all_data()
# Out:
# This file does not exist:  FRC_data.csv
# This file does not exist:  GL_data.csv
# This file does not exist:  MKTX_data.csv
# This file does not exist:  MSCI_data.csv
# This file does not exist:  SIVB_data.csv
# This file does not exist:  TFC_data.csv
# This file does not exist:  WRB_data.csv

# %%
finance.create_dataframe()  # Create a dataframe for the data

# %% [markdown]
# Suppose we want to predict the price of the stock "CBOE" on day t, by using the prices of some other stocks in the past few days.
#
# More specifically, for example predicting the "close" price of "CBOE" on day 10, given that we have "close" prices of "AFL", "ALL", etc on day 9, day 8, day 7 or more before.
#
# In the rest of this analysis, all the prices of CBOE will never be considered as an independent variable. That means the "open", "high", etc of CBOE will never be included as a feature in the training set in the models. Therefore it is expected that the prediction results would probably be worse than using CBOE"s own past prices, but it is still worthwhile to explore the impact of other stock prices on CBOE's price which is to be done in this analysis.
#
# First create the dataframe for "CBOE"

# %%
cboe = finance.stock("CBOE")

# %%
finance.plot_trend(cboe.iloc[:,:-1])

# %% [markdown]
# We will now try to predict the "close" price in the rest of this analysis.
# To predict the "close" price of CBOE, first we will need a dataframe with the "close" price of all stocks, with that column of CBOE in the front, and a column of dates.

# %%
tdf = finance.dataframe_by_price_type("close")  # Create a dataframe of all the "close" prices called "tdf"
tdf.dropna(axis=1, inplace=True)  # To deal with missing values, all the stocks with nan values are dropped
# Rearrange the dataframe
tdf_col = list(tdf.columns)
new_col = []
new_col.append(tdf_col.pop(tdf_col.index("date")))
new_col.append(tdf_col.pop(tdf_col.index("close_CBOE")))
new_col += tdf_col
tdf = tdf[new_col]

# %%
# Now look at how the dataframe looks like
print(tdf.head())
# Out:
#          date  close_CBOE  close_AFL  close_ALL  close_AXP  close_AIG  \
# 0  2013-02-08       34.46      50.35      45.14      61.80      38.79
# 1  2013-02-11       34.78      50.26      45.25      61.98      39.45
# 2  2013-02-12       34.96      49.50      45.61      62.20      38.63
# 3  2013-02-13       34.99      48.65      45.88      62.10      38.87
# 4  2013-02-14       35.69      48.83      45.88      62.34      39.21
#
#    close_AMP  close_AON  close_AJG  close_AIZ  ...  close_RJF  close_RF  \
# 0      66.49      56.53      37.97      38.56  ...      45.31      7.93
# 1      66.49      56.66      37.88      38.48  ...      45.32      7.94
# 2      67.49      56.70      37.82      41.05  ...      45.41      7.93
# 3      67.89      57.28      38.54      41.39  ...      45.58      7.85
# 4      69.04      57.30      38.82      42.01  ...      45.60      7.91
#
#    close_SPGI  close_STT  close_TROW  close_TRV  close_USB  close_UNM  \
# 0       42.67      56.55       73.27      78.86      33.65      24.06
# 1       44.28      56.60       73.13      79.21      34.09      24.17
# 2       44.03      56.93       73.75      79.90      34.31      24.17
# 3       44.33      57.07       74.21      79.99      33.93      24.49
# 4       44.86      57.20       73.84      80.34      33.99      24.40
#
#    close_WFC  close_ZION
# 0      34.88       24.14
# 1      35.26       24.21
# 2      35.51       24.49
# 3      35.13       24.74
# 4      35.21       24.63
#
# [5 rows x 56 columns]

# %% [markdown]
# Since the is a time series, including the dates as a variable would be inappropriate. However the date may have impact on the stock prices. To take care of this, one hot encoding is used and five binary variables are created to represent Monday to Friday. If it is Monday, the "Mon" varaible will be 1, else will be 0.

# %%
wday = pd.DataFrame(pd.to_datetime(cboe["date"].copy(deep=True)))
days = ["Mon", "Tue", "Wed", "Thu", "Fri"]
for i in range(len(days)):
    wday[days[i]] = wday["date"].apply(lambda x: 1 if x.weekday() == i else 0)
wday.drop("date", axis=1, inplace=True)
tdf = tdf.iloc[:,:2].join(wday.join(tdf.iloc[:,2:]))

# %%
# Now look at how the new dataframe looks like
print(tdf.head())
# Out:
#          date  close_CBOE  Mon  Tue  Wed  Thu  Fri  close_AFL  close_ALL  \
# 0  2013-02-08       34.46    0    0    0    0    1      50.35      45.14
# 1  2013-02-11       34.78    1    0    0    0    0      50.26      45.25
# 2  2013-02-12       34.96    0    1    0    0    0      49.50      45.61
# 3  2013-02-13       34.99    0    0    1    0    0      48.65      45.88
# 4  2013-02-14       35.69    0    0    0    1    0      48.83      45.88
#
#    close_AXP  ...  close_RJF  close_RF  close_SPGI  close_STT  close_TROW  \
# 0      61.80  ...      45.31      7.93       42.67      56.55       73.27
# 1      61.98  ...      45.32      7.94       44.28      56.60       73.13
# 2      62.20  ...      45.41      7.93       44.03      56.93       73.75
# 3      62.10  ...      45.58      7.85       44.33      57.07       74.21
# 4      62.34  ...      45.60      7.91       44.86      57.20       73.84
#
#    close_TRV  close_USB  close_UNM  close_WFC  close_ZION
# 0      78.86      33.65      24.06      34.88       24.14
# 1      79.21      34.09      24.17      35.26       24.21
# 2      79.90      34.31      24.17      35.51       24.49
# 3      79.99      33.93      24.49      35.13       24.74
# 4      80.34      33.99      24.40      35.21       24.63
#
# [5 rows x 61 columns]

# %% [markdown]
# It seems now the dataframe for the analysis is ready. Now a class "Dataset" is created, the purpose of which is to generate a new dataframe containing the lagged price of the stocks. The lag is a hyperparameter to be specified upon the instanization.
# More specifically, if the lag is 3, the row of day 4 will contain columns of the stock prices of day 1, day 2 and day 3.
#
# In other words, columns "close_{stock}_1", "close_{stock}_2", "close_{stock}_3" responsible for the past 3 day prices will be created for stock = {stock}.

# %%
# Create a class "Dataset" that creates a dataframe for the data analysis
class Dataset:
    def __init__(self, df, lag):
        self.lag = lag
        self.df = df
        self.names = list(df.columns[7:])
        self.dates = df.iloc[:,0].copy(deep=True)

    # Generate the independent dataframe
    def gen_x(self):
        self.x_df = self.df.iloc[:,7:].copy(deep=True)
        for name in self.names:
            for k in range(1, self.lag + 1):
                self.x_df[name + "_" + str(k)] = np.zeros(self.x_df.shape[0])
        i = self.lag
        while i <= self.x_df.shape[0]:
            for name in self.names:
                for k in range(1, self.lag + 1):
                    self.x_df[name + "_" + str(k)][i] = self.x_df[name][i - k]
            i += 1
        for name in self.names:
            self.x_df.drop(name, axis=1, inplace=True)
        self.x_df = wday.join(self.x_df)

    # Generate the dependent dataframe
    def gen_y(self):
        self.y_df = self.df.iloc[:,1].copy(deep=True)

    # Split the dataframe into training and testing parts
    def train_test_split(self, n_split=0.8):
        self.n = int(self.x_df.shape[0] * n_split)
        self.x_train = self.x_df[self.lag:self.n]
        self.x_test = self.x_df[self.n:]
        self.y_train = self.y_df[self.lag:self.n]
        self.y_test = self.y_df[self.n:]
        return self.x_train, self.y_train, self.x_test, self.y_test

    # Plot the predicted data and the real data
    def plot_performance(self, y_pred):
        y_series = pd.Series(list(self.y_df), index = self.dates)
        y_predict = y_series[self.lag:self.n].append(pd.Series(y_pred, index=self.dates[self.n:]))
        mse = mean_squared_error(y_test, y_pred)
        plt.plot(y_predict, "r", label = "Predicted Data")
        plt.plot(y_series, "b", label = "Real Data")
        plt.axvline(x=self.dates[self.n], linestyle="dashed", label="Prediction starts")
        plt.xlabel("Date")
        plt.ylabel("Price (USD)")
        plt.title("Predicted Data versus Real Data, MSE = {mse}".format(mse = mse))
        plt.legend()
        plt.show()

# %%
# Create a dataset for the analysis with lag 2
dataset = Dataset(tdf, 2)
# Generate the independent and dependent dataset
dataset.gen_x()
dataset.gen_y()
x_train, y_train, x_test, y_test = dataset.train_test_split()

# %% [markdown]
# The training data with lag 2 looks like below.
# Row 2 is the day 3 (Since the index starts from 0), which is a Tuesday, "close_AFL_1" and "close_AFL_2" are the prices of day 2 and day 1 respectively.

# %%
print(x_train.head())
print(y_train.head())
# Out:
#    Mon  Tue  Wed  Thu  Fri  close_AFL_1  close_AFL_2  close_ALL_1  \
# 2    0    1    0    0    0        50.26        50.35        45.25
# 3    0    0    1    0    0        49.50        50.26        45.61
# 4    0    0    0    1    0        48.65        49.50        45.88
# 5    0    0    0    0    1        48.83        48.65        45.88
# 6    0    1    0    0    0        49.34        48.83        45.85
#
#    close_ALL_2  close_AXP_1  ...  close_TRV_1  close_TRV_2  close_USB_1  \
# 2        45.14        61.98  ...        79.21        78.86        34.09
# 3        45.25        62.20  ...        79.90        79.21        34.31
# 4        45.61        62.10  ...        79.99        79.90        33.93
# 5        45.88        62.34  ...        80.34        79.99        33.99
# 6        45.88        61.69  ...        80.39        80.34        33.91
#
#    close_USB_2  close_UNM_1  close_UNM_2  close_WFC_1  close_WFC_2  \
# 2        33.65        24.17        24.06        35.26        34.88
# 3        34.09        24.17        24.17        35.51        35.26
# 4        34.31        24.49        24.17        35.13        35.51
# 5        33.93        24.40        24.49        35.21        35.13
# 6        33.99        24.46        24.40        35.16        35.21
#
#    close_ZION_1  close_ZION_2
# 2         24.21         24.14
# 3         24.49         24.21
# 4         24.74         24.49
# 5         24.63         24.74
# 6         24.34         24.63
#
# [5 rows x 113 columns]
# 2    34.96
# 3    34.99
# 4    35.69
# 5    35.96
# 6    35.80
# Name: close_CBOE, dtype: float64

# %% [markdown]
# Now a function plot_cv is created, which will create 4 dataframes with lags 1, 2, 3 and 4. It will then fit in the model with the data and make cross validation prediction.
#
# The first 80% days in the training set will be used for training while the next 20% days will be used for cross validation.

# %%
def plot_cv(model):
    lags = [1, 2, 3, 4]
    fig = plt.figure(figsize=(28, 20))
    for i in range(4):
        dataset = Dataset(tdf, lags[i])
        dataset.gen_x()
        dataset.gen_y()
        x_train, y_train, x_test, y_test = dataset.train_test_split()
        cv = int(y_train.shape[0] * 0.8)
        end = int(y_train.shape[0])
        model.fit(x_train[:cv], y_train[:cv])
        y_pred = model.predict(x_train[cv:])
        y_series = pd.Series(list(dataset.y_df[:end]), index=dataset.dates[:end])
        y_predict = y_series[dataset.lag:cv].append(pd.Series(y_pred, index=dataset.dates[cv:end]))
        mse = mean_squared_error(y_train[cv:], y_pred)
        ax = fig.add_subplot(2, 2, i + 1)
        ax.plot(y_predict, "r", label="Predicted Data")
        ax.plot(y_series, "b", label="Real Data")
        ax.axvline(x=dataset.dates[cv], linestyle="dashed", label="Cross validation starts")
        ax.title.set_text("Using lag {lag} and results in MSE: {mse}".format(lag=lags[i], mse=mse))
        ax.legend()
    plt.show()

# %% [markdown]
# In this prediction, linear regression and mean squared error are used as the regressor and the loss metrics respectively.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
lin_reg = LinearRegression(fit_intercept=False)
plot_cv(lin_reg)

# %% [markdown]
# It seems the model using the lag 2 data has the lowest MSE.
# The lag 2 dataset is then used to make predictions on the testing set

# %%
# Create a dataset for the analysis with lag 2
dataset = Dataset(tdf, 2)
dataset.gen_x()
dataset.gen_y()
x_train, y_train, x_test, y_test = dataset.train_test_split()
lin_reg = LinearRegression(fit_intercept=False)
cv = int(y_train.shape[0] * 0.8)
end = int(y_train.shape[0])
lin_reg.fit(x_train[:cv], y_train[:cv])
y_pred = lin_reg.predict(x_train[cv:])
y_series = pd.Series(list(dataset.y_df[:end]), index=dataset.dates[:end])
y_predict = y_series[dataset.lag:cv].append(pd.Series(y_pred, index=dataset.dates[cv:end]))
mse = mean_squared_error(y_train[cv:], y_pred)
lin_reg.fit(x_train, y_train)
# Predict the stock price of "CBOE" using the trained model
y_pred = lin_reg.predict(x_test)
# Plot the predicted and the real data
fig = plt.figure(figsize=(15,10))
dataset.plot_performance(y_pred)

# %% [markdown]
# It turns out that the prediction is terrible, though it worked not bad in the cross validation set.

# %%
# Predict the training data using the trained model
y_train_pred = lin_reg.predict(x_train)
# Plot to see the fitting of the model
mse = mean_squared_error(y_train, y_train_pred)
fig = plt.figure(figsize=(15,10))
plt.plot(y_train, "b", label = "Real training")
plt.plot(y_train_pred, "r", label = "Predicted training")
plt.xlabel("Time")
plt.ylabel("Price (USD)")
plt.title("Model fitness of lag 2 model, MSE = {mse}".format(mse = mse))
plt.legend()
plt.show()

# %% [markdown]
# Then Decision tree regressor is tried.
# They obtain generally lower MSE compared to linear model, but they just look terrible.
#
# Perhaps decision tree may just not be suitable to regress highly fluctuating data like this.

# %%
from sklearn.tree import DecisionTreeRegressor
tree_reg = DecisionTreeRegressor()
plot_cv(tree_reg)

# %% [markdown]
# Considered that the linear model produced earlier may have overfitted the data, and that some lags variable may be redundant and not contribute much to the prediction.
#
# Regularization is tried here to curb this problem. Elasticnet is used to introduce LASSO and Ridge terms in the model, and Gridsearch is implemented to find the potentially best estimator.

# %%
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import GridSearchCV
param_grid = [
    {"alpha": [0.1, 0.05, 0.03, 0.01, 0.001], "l1_ratio": [0, 0.1, 0.5, 0.9, 1]}
]
elastic_net = ElasticNet()
grid_search = GridSearchCV(elastic_net, param_grid, scoring="neg_mean_squared_error", return_train_score=True)
cv = int(y_train.shape[0] * 0.8)
grid_search.fit(x_train[:cv],y_train[:cv])
# Out:
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 467.37570892180423, tolerance: 2.6234886770650085
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 470.5510337668852, tolerance: 6.087531993825817
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 528.0747455065323, tolerance: 5.8832851994678075
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 450.8880836264655, tolerance: 5.706036938225193
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 437.55239874060567, tolerance: 4.014308258312422
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 465.07181580003976, tolerance: 2.6234886770650085
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 459.7476840490932, tolerance: 6.087531993825817
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 537.3620884411623, tolerance: 5.8832851994678075
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 468.75204524386106, tolerance: 5.706036938225193
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 468.81532476491276, tolerance: 4.014308258312422
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 146.85679644600077, tolerance: 2.6234886770650085
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 394.25360205660047, tolerance: 6.087531993825817
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 576.4009705989293, tolerance: 5.8832851994678075
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 440.2280089871508, tolerance: 5.706036938225193
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 554.3089849886803, tolerance: 4.014308258312422
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.337202756858119, tolerance: 2.6234886770650085
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 287.02367772100706, tolerance: 6.087531993825817
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 576.7648699333572, tolerance: 5.8832851994678075
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 179.87536261681834, tolerance: 5.706036938225193
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 509.02061878816556, tolerance: 4.014308258312422
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.684411439820565, tolerance: 2.6234886770650085
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152.4118096214712, tolerance: 6.087531993825817
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 518.6792973259651, tolerance: 5.8832851994678075
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 284.55048078140703, tolerance: 5.706036938225193
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 466.0092295493784, tolerance: 4.014308258312422
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 442.4973723497849, tolerance: 2.6234886770650085
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 441.1749672608142, tolerance: 6.087531993825817
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 492.9850025364233, tolerance: 5.8832851994678075
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 420.4947263784531, tolerance: 5.706036938225193
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 403.7621746281596, tolerance: 4.014308258312422
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 452.8006730527452, tolerance: 2.6234886770650085
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 453.7129106610324, tolerance: 6.087531993825817
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 500.45223608765264, tolerance: 5.8832851994678075
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 435.469588540026, tolerance: 5.706036938225193
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 421.5957059480496, tolerance: 4.014308258312422
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 416.4627554249561, tolerance: 2.6234886770650085
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 426.0067033282166, tolerance: 6.087531993825817
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 520.5743613310608, tolerance: 5.8832851994678075
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 446.0961073393189, tolerance: 5.706036938225193
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 473.2796025440705, tolerance: 4.014308258312422
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 312.7071821389833, tolerance: 2.6234886770650085
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 362.2542165796762, tolerance: 6.087531993825817
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 557.1603918545555, tolerance: 5.8832851994678075
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 420.3609302893243, tolerance: 5.706036938225193
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 519.4066265342368, tolerance: 4.014308258312422
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 189.0337485428796, tolerance: 2.6234886770650085
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 371.7604855565197, tolerance: 6.087531993825817
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 560.9427580775009, tolerance: 5.8832851994678075
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 400.37899201357357, tolerance: 5.706036938225193
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 523.8748773932482, tolerance: 4.014308258312422
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 429.602037705537, tolerance: 2.6234886770650085
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 422.3725234110553, tolerance: 6.087531993825817
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 474.3654806213646, tolerance: 5.8832851994678075
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 403.96202483893705, tolerance: 5.706036938225193
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 384.59231786422436, tolerance: 4.014308258312422
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 438.2518551645521, tolerance: 2.6234886770650085
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 435.6060303268568, tolerance: 6.087531993825817
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 481.2276628754149, tolerance: 5.8832851994678075
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 414.58635820576194, tolerance: 5.706036938225193
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 393.69655858348943, tolerance: 4.014308258312422
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 436.66343313697774, tolerance: 2.6234886770650085
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 424.2016493008735, tolerance: 6.087531993825817
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 485.60244951041165, tolerance: 5.8832851994678075
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 431.8860544084983, tolerance: 5.706036938225193
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 429.8081968017293, tolerance: 4.014308258312422
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 387.21763500745556, tolerance: 2.6234886770650085
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 421.56111228720306, tolerance: 6.087531993825817
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 511.0670309498701, tolerance: 5.8832851994678075
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 437.589145838714, tolerance: 5.706036938225193
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 452.21001001166115, tolerance: 4.014308258312422
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 430.87911753304786, tolerance: 2.6234886770650085
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 425.31334728143895, tolerance: 6.087531993825817
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 513.9312488250318, tolerance: 5.8832851994678075
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 429.7127017442274, tolerance: 5.706036938225193
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 464.04420150782704, tolerance: 4.014308258312422
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 410.798718809078, tolerance: 2.6234886770650085
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 389.04603785219496, tolerance: 6.087531993825817
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 449.8250239082355, tolerance: 5.8832851994678075
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 381.5173333850486, tolerance: 5.706036938225193
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 357.28418772540226, tolerance: 4.014308258312422
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 415.3615461031637, tolerance: 2.6234886770650085
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 395.5272610444355, tolerance: 6.087531993825817
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 453.2003862230864, tolerance: 5.8832851994678075
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 385.9690896614229, tolerance: 5.706036938225193
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 361.4062370867332, tolerance: 4.014308258312422
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 425.7640854494995, tolerance: 2.6234886770650085
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 416.30118745992417, tolerance: 6.087531993825817
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 462.194229454148, tolerance: 5.8832851994678075
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 400.2527468385637, tolerance: 5.706036938225193
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 372.6506224333673, tolerance: 4.014308258312422
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 427.2313731036491, tolerance: 2.6234886770650085
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 428.6856049162992, tolerance: 6.087531993825817
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 467.14383535869206, tolerance: 5.8832851994678075
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 406.3726307192434, tolerance: 5.706036938225193
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 388.5436103290589, tolerance: 4.014308258312422
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 427.4402340321689, tolerance: 2.6234886770650085
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 429.51499730878834, tolerance: 6.087531993825817
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 467.9220152348441, tolerance: 5.8832851994678075
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 407.936555704338, tolerance: 5.706036938225193
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 392.876340889237, tolerance: 4.014308258312422
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 395.3952186787444, tolerance: 2.6234886770650085
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 356.87743956729236, tolerance: 6.087531993825817
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 433.66316388237755, tolerance: 5.8832851994678075
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 366.3233135121759, tolerance: 5.706036938225193
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 336.91428501355506, tolerance: 4.014308258312422
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 396.0931815727432, tolerance: 2.6234886770650085
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 357.7094400302097, tolerance: 6.087531993825817
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 434.0746660238167, tolerance: 5.8832851994678075
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 366.8374594064098, tolerance: 5.706036938225193
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 337.5499101703529, tolerance: 4.014308258312422
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 398.7392510033975, tolerance: 2.6234886770650085
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 361.01802607824783, tolerance: 6.087531993825817
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 435.6445854376903, tolerance: 5.8832851994678075
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 368.82176127563054, tolerance: 5.706036938225193
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 339.9737569083738, tolerance: 4.014308258312422
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 401.04484982747533, tolerance: 2.6234886770650085
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 364.28974248059296, tolerance: 6.087531993825817
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 437.1113396243988, tolerance: 5.8832851994678075
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 370.65228724150137, tolerance: 5.706036938225193
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 342.17718795119237, tolerance: 4.014308258312422
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 401.57143754630675, tolerance: 2.6234886770650085
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 365.1008316906507, tolerance: 6.087531993825817
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 437.47404201820353, tolerance: 5.8832851994678075
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 371.29369991874927, tolerance: 5.706036938225193
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 342.69062224426926, tolerance: 4.014308258312422
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 495.5524102802365, tolerance: 6.397961388053733
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(estimator=ElasticNet(),
#              param_grid=[{'alpha': [0.1, 0.05, 0.03, 0.01, 0.001],
#                           'l1_ratio': [0, 0.1, 0.5, 0.9, 1]}],
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
elastic_net = ElasticNet(alpha=0.1, l1_ratio=0.9)
plot_cv(elastic_net)
# Out:
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 495.1692954575483, tolerance: 6.428029932053732
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 495.5524102802365, tolerance: 6.397961388053733
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 553.4881537398426, tolerance: 6.358028112618678
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 641.7725884056215, tolerance: 6.318115286943141
#   model = cd_fast.enet_coordinate_descent(

# %%
elastic_net = ElasticNet(alpha=0.03, l1_ratio=1)
plot_cv(elastic_net)
# Out:
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 763.5661079435076, tolerance: 6.428029932053732
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 740.5200862987471, tolerance: 6.397961388053733
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 696.8032044543606, tolerance: 6.358028112618678
#   model = cd_fast.enet_coordinate_descent(
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 655.0765978986665, tolerance: 6.318115286943141
#   model = cd_fast.enet_coordinate_descent(

# %%
all_data = {}
for stock in list(snf_table.symbol):
    try:
        data_file = open("S&P500 Data/individual_stocks_5yr/individual_stocks_5yr/{name}_data.csv". \
                         format(name=stock), "r")
        all_data[stock] = pd.read_csv(data_file)
    except OSError:
        print("This file does not exist: ", stock + "_data.csv")

all_df = pd.DataFrame()
all_df["date"] = all_data[list(all_data.keys())[0]]["date"]
for stock in list(all_data.keys()):
    all_data[stock].drop(["date", "Name"], axis=1, inplace=True)
    all_data[stock].columns = [str(name) + "_" + str(stock) for name in list(all_data[stock].columns)]
    all_df = all_df.join(all_data[stock])
# Out:
# This file does not exist:  ABMD_data.csv
# This file does not exist:  AMCR_data.csv
# This file does not exist:  ANET_data.csv
# This file does not exist:  ATO_data.csv
# This file does not exist:  BKR_data.csv
# This file does not exist:  BIO_data.csv
# This file does not exist:  BKNG_data.csv
# This file does not exist:  BR_data.csv
# This file does not exist:  CARR_data.csv
# This file does not exist:  CBRE_data.csv
# This file does not exist:  CDW_data.csv
# This file does not exist:  CE_data.csv
# This file does not exist:  CPRT_data.csv
# This file does not exist:  CTVA_data.csv
# This file does not exist:  DXCM_data.csv
# This file does not exist:  FANG_data.csv
# This file does not exist:  DPZ_data.csv
# This file does not exist:  DOW_data.csv
# This file does not exist:  DD_data.csv
# This file does not exist:  EVRG_data.csv
# This file does not exist:  FRC_data.csv
# This file does not exist:  FLT_data.csv
# This file does not exist:  FTNT_data.csv
# This file does not exist:  GL_data.csv
# This file does not exist:  PEAK_data.csv
# This file does not exist:  HFC_data.csv
# This file does not exist:  HWM_data.csv
# This file does not exist:  IEX_data.csv
# This file does not exist:  IPGP_data.csv
# This file does not exist:  JKHY_data.csv
# This file does not exist:  J_data.csv
# This file does not exist:  KEYS_data.csv
# This file does not exist:  LHX_data.csv
# This file does not exist:  LW_data.csv
# This file does not exist:  LVS_data.csv
# This file does not exist:  LDOS_data.csv
# This file does not exist:  LIN_data.csv
# This file does not exist:  LYV_data.csv
# This file does not exist:  MKTX_data.csv
# This file does not exist:  MXIM_data.csv
# This file does not exist:  MSCI_data.csv
# This file does not exist:  NLOK_data.csv
# This file does not exist:  NVR_data.csv
# This file does not exist:  ODFL_data.csv
# This file does not exist:  OTIS_data.csv
# This file does not exist:  PAYC_data.csv
# This file does not exist:  RTX_data.csv
# This file does not exist:  ROL_data.csv
# This file does not exist:  NOW_data.csv
# This file does not exist:  STE_data.csv
# This file does not exist:  SIVB_data.csv
# This file does not exist:  TMUS_data.csv
# This file does not exist:  TTWO_data.csv
# This file does not exist:  TFX_data.csv
# This file does not exist:  TT_data.csv
# This file does not exist:  TDY_data.csv
# This file does not exist:  TFC_data.csv
# This file does not exist:  TWTR_data.csv
# This file does not exist:  TYL_data.csv
# This file does not exist:  VIAC_data.csv
# This file does not exist:  WRB_data.csv
# This file does not exist:  WAB_data.csv
# This file does not exist:  WELL_data.csv
# This file does not exist:  WST_data.csv
# This file does not exist:  ZBRA_data.csv

# %%
df = pd.DataFrame(all_df["date"].copy(deep=True))
for col_name in list(all_df.columns)[1:]:
    for name in ["close"]:
        if name in col_name:
            df = df.join(all_df[col_name])

df.dropna(axis=1, inplace=True)  # Drop all the columns with nan
# Rearrange the dataframe
df_col = list(df.columns)
new_col = []
new_col.append(df_col.pop(df_col.index("date")))
new_col.append(df_col.pop(df_col.index("close_CBOE")))
new_col += df_col
new_tdf = df[new_col]

# %%
n = 1007
diff_df = df[["date", "close_CBOE"]][:1007].copy(deep=True)
for name in list(df.columns[2:]):
    diff_df[str("diff") + str(name[5:])] = df[name][:1007] - diff_df["close_CBOE"][:1007]

from statsmodels.tsa.stattools import adfuller
adf_stat = pd.DataFrame(np.zeros((len(diff_df.columns[2:]), 2)), index = list(diff_df.columns[2:]), columns = ["Statistic", "p_value"])
for name in list(diff_df.columns[2:]):
    adf_stat["Statistic"][str(name)] = adfuller(diff_df[name])[0]
    adf_stat["p_value"][str(name)] = adfuller(diff_df[name])[1]

adf_filtered = adf_stat[adf_stat["Statistic"] < 0].copy(deep=True)
adf_filtered = adf_filtered[adf_filtered["p_value"] < 0.1]

dependent_stock_names = ["close_" + name[5:] for name in adf_filtered.index]

new_tdf_1 = new_tdf.copy(deep=True)
for stock in list(new_tdf_1.columns[2:]):
    if stock not in dependent_stock_names:
        new_tdf_1.drop(stock, axis=1, inplace=True)

finance.plot_trend(new_tdf_1)

newttdf = new_tdf_1.iloc[:,:2].join(wday.join(new_tdf_1.iloc[:,2:]))
new_tdf_1 = newttdf
# Out:
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\statsmodels\regression\linear_model.py:889: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
# c:\users\horch\appdata\local\programs\python\python38-32\lib\site-packages\statsmodels\base\model.py:1362: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse

# %%
lags = [1, 2, 3, 5]
fig = plt.figure(figsize=(28,20))
for i in range(4):
    dataset = Dataset(new_tdf_1, lags[i])
    dataset.gen_x()
    dataset.gen_y()
    x_train, y_train, x_test, y_test = dataset.train_test_split()
    lin_reg = LinearRegression(fit_intercept=False)
    cv = int(y_train.shape[0] * 0.8)
    end = int(y_train.shape[0])
    lin_reg.fit(x_train[:cv], y_train[:cv])
    y_pred = lin_reg.predict(x_train[cv:])
    y_series = pd.Series(list(dataset.y_df[:end]), index=dataset.dates[:end])
    y_predict = y_series[dataset.lag:cv].append(pd.Series(y_pred, index=dataset.dates[cv:end]))
    mse = mean_squared_error(y_train[cv:], y_pred)
    ax = fig.add_subplot(2, 2, i+1)
    ax.plot(y_predict, "r", label="Predicted Data")
    ax.plot(y_series, "b", label="Real Data")
    ax.axvline(x=dataset.dates[cv], linestyle="dashed", label="Cross validation starts")
    ax.title.set_text("Using lag {lag} and results in MSE: {mse}".format(lag=lags[i], mse = mse))
    ax.legend()
plt.show()
